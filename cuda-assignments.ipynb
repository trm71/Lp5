# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Mon_Apr__3_17:16:06_PDT_2023
# Cuda compilation tools, release 12.1, V12.1.105
# Build cuda_12.1.r12.1/compiler.32688072_0

# %%
# !nvcc /kaggle/input/reduce/3_Parallel_Reduction.cu -o reduce_f
# Out:
# cc1plus: fatal error: cuda_runtime.h: No such file or directory
# compilation terminated.

# %%
# !apt-get update
# !apt-get install -y cuda-toolkit
# Out:
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu focal-updates InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Hit:5 https://packages.cloud.google.com/apt gcsfuse-focal InRelease
# Hit:6 https://packages.cloud.google.com/apt cloud-sdk InRelease
# Hit:7 https://packages.cloud.google.com/apt google-fast-socket InRelease
# Hit:8 http://security.ubuntu.com/ubuntu focal-security InRelease
# Reading package lists... Done
# E: dpkg was interrupted, you must manually run 'dpkg --configure -a' to correct the problem.

# %%
# !nvcc /kaggle/input/reduce/3_Parallel_Reduction.cu -o reduce_f
# Out:
# cc1plus: fatal error: cuda_runtime.h: No such file or directory
# compilation terminated.

# %%
# !apt-get install -y cuda-toolkit
# Out:
# E: dpkg was interrupted, you must manually run 'dpkg --configure -a' to correct the problem.

# %%
# !dpkg --configure -a

# %%
# !apt-get install -y cuda-toolkit
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   cuda-nvvp-12-4 cuda-toolkit-12-4 cuda-tools-12-4 cuda-visual-tools-12-4
#   gds-tools-12-4
# The following NEW packages will be installed:
#   cuda-toolkit cuda-toolkit-12-4 cuda-tools-12-4 cuda-visual-tools-12-4
#   gds-tools-12-4
# The following packages will be upgraded:
#   cuda-nvvp-12-4
# 1 upgraded, 5 newly installed, 0 to remove and 73 not upgraded.
# 1 not fully installed or removed.
# Need to get 154 MB of archives.
# After this operation, 198 MB of additional disk space will be used.
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-nvvp-12-4 12.4.127-1 [115 MB]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-visual-tools-12-4 12.4.1-1 [2938 B]
# ...

# %%
# !nvcc /kaggle/input/reduce/3_Parallel_Reduction.cu -o reduce_f
# Out:
# cc1plus: fatal error: cuda_runtime.h: No such file or directory
# compilation terminated.

# %%
# !apt-get install -y cuda-toolkit
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# cuda-toolkit is already the newest version (12.4.1-1).
# 0 upgraded, 0 newly installed, 0 to remove and 73 not upgraded.

# %%
# !nvcc /kaggle/input/reduce/3_Parallel_Reduction.cu -o reduce_f
# Out:
# cc1plus: fatal error: cuda_runtime.h: No such file or directory
# compilation terminated.

# %%
# !nvcc --include-path=/usr/local/cuda/include /kaggle/input/parallel/parallel.cu -o reduce_f -L/usr/local/cuda/lib64 -lcudart -lcudadevrt -lcudart_static

# %%
# !./reduce_f
# Out:
# Minimum value: 1
# Maximum value: 256
# Sum: 32896
# Average: 128.50

# %%
# !nvcc --include-path=/usr/local/cuda/include /kaggle/input/a4a4a4/4_vector_addition.cu -o reduce_f
# Out:
# /usr/bin/ld: cannot find -lcudadevrt
# /usr/bin/ld: cannot find -lcudart_static
# collect2: error: ld returned 1 exit status

# %%
# !nvcc --include-path=/usr/local/cuda/include /kaggle/input/a4a4a4/4_vector_addition.cu -o v_add -L/usr/local/cuda/lib64 -lcudart -lcudadevrt -lcudart_static

# %%
# !./v_add
# Out:
# Vector A: 3 6 7 5
# Vector B: 3 5 6 2
# Addition: 6 11 13 7

# %%
# !nvcc --include-path=/usr/local/cuda/include /kaggle/input/a4a4a4/4_matrix_multiplication.cu -o m_mul -L/usr/local/cuda/lib64 -lcudart -lcudadevrt -lcudart_static
# !./m_mul
# Out:
# /kaggle/input/a4a4a4/4_matrix_multiplication.cu(43): warning #177-D: variable "blockSize" was declared but never referenced
#       int blockSize = 16;
#           ^
#
# Remark: The warnings can be suppressed with "-diag-suppress <warning-number>"
#
# Matrix A:
# 3 6
# 7 5
#
# Matrix B:
# 3 5
# 6 2
#
# Multiplication of matrix A and B:
# 45 27
# 51 45
